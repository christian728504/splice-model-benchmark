# %%
import polars as pl
import numpy as np
import subprocess
import os
os.chdir('/zata/zippy/ramirezc/splice-model-benchmark/golden_standard')
from IPython.display import display
import matplotlib.pyplot as plt

# %%
chroms = [f"chr{x}" for x in range(1, 23)] + ["chrX", "chrY"]
shortread_introns_df = pl.read_csv("all_shortread_introns.tab", separator="\t").with_columns(pl.col("chrom").cast(pl.Enum(chroms))).sort("chrom", "start", "strand")
shortread_introns_df.with_columns(pl.lit(".").alias("score"), pl.lit(".").alias("name")).select("chrom", "start", "end", "name", "score", "strand").write_csv("all_shortread_introns.bed", separator="\t", include_header=False)
shortread_introns_standardized = shortread_introns_df.with_columns(
    ((pl.col("reads") - pl.col("reads").mean()) / pl.col("reads").std()).alias("reads_standardized")
)
display(shortread_introns_standardized)

longread_introns_df = pl.read_csv("all_longread_introns.tab", separator="\t").with_columns(pl.col("chrom").cast(pl.Enum(chroms))).sort("chrom", "start", "strand")
longread_introns_df.with_columns(pl.lit(".").alias("score"), pl.lit(".").alias("name")).select("chrom", "start", "end", "name", "score", "strand").write_csv("all_longread_introns.bed", separator="\t", include_header=False)
longread_introns_standardized = longread_introns_df.with_columns(
    ((pl.col("reads") - pl.col("reads").mean()) / pl.col("reads").std()).alias("reads_standardized")
)
display(longread_introns_standardized)

# %%
display(shortread_introns_standardized.select('reads', 'reads_standardized').describe())
display(longread_introns_standardized.select('reads', 'reads_standardized').describe())

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

plt.style.use('cowplot')
fig.suptitle('Standard Sclaed Read Distribution for long and short read RNA-seq datasets', fontsize=16)
fig.supxlabel('Standard Scaled Reads')
fig.supylabel('Frequency')
axes[0].hist(np.log2(longread_introns_standardized['reads_standardized']), bins=200, alpha=0.5, label='Read Length')
axes[0].set_title('Long Read RNA-seq')
axes[1].hist(np.log2(shortread_introns_standardized['reads_standardized']), bins=200, alpha=0.5, label='Read Length')
axes[1].set_title('Total Read RNA-seq')
for axis in axes:
    y_ticks = axis.get_yticks()
    padding = y_ticks[1] * 0.1
    y_lim_min = y_ticks[0] - padding
    axis.set_ylim(bottom=y_lim_min)
plt.show()

# %%
cmd = [
    "bedtools", "jaccard", 
    "-a", "all_shortread_introns.bed",
    "-b", "all_longread_introns.bed"
]
jaccard_stats = subprocess.run(cmd, capture_output=True, text=True)
print(jaccard_stats.stdout)
# Out:
# intersection	union	jaccard	n_intersections
# 2039488805	2531104536	0.80577	65046

# %% [markdown]
# Strand specific jaccard is not right, it seems that the standedness is being mixed up between the different platforms and interpretations of the data from pysam. I'm going to manually parse the BAM flags to get the most accuracte strand information.

# %%
import pysam

file_prefix = "/zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/{biosample}/{file}.filtered.bam"
metadata = pl.read_csv("/zata/zippy/ramirezc/splice-model-benchmark/golden_standard/biosample_matched_rna_seq_experiments.tsv", separator="\t")

file_paths = []
for row in metadata.iter_rows(named=True):
    file_acc = row["File accession"]
    biosample_acc = row["Biosample accession"]
    file_paths.append(file_prefix.format(biosample=biosample_acc, file=file_acc))

def is_paired_end(bam_path):
    """Check if a BAM file is paired-end by examining the first 1000 reads"""
    with pysam.AlignmentFile(bam_path, "rb") as bam:
        for i, read in enumerate(bam):
            if read.is_paired:
                return True
            if i >= 1000:
                break
        return False

for bam_file in file_paths:
    paired = is_paired_end(bam_file)
    if paired is True:
        print(f"{bam_file}: Paired-end")
    elif paired is False:
        print(f"{bam_file}: Single-end")
    else:
        print(f"{bam_file}: Error checking file")
# Out:
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS481WHG/ENCFF068AID.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS660AUE/ENCFF791RZL.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS422TMB/ENCFF083LBA.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS644WSW/ENCFF808UYE.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS105DDE/ENCFF635SRJ.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS819UHF/ENCFF349PBM.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS481WHG/ENCFF564ONS.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS914REQ/ENCFF502LAB.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS756BZF/ENCFF623IBV.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS075YII/ENCFF899RYN.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS020DQC/ENCFF835KGV.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS060KJN/ENCFF320GCF.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS119CST/ENCFF045ZQI.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS777OZT/ENCFF745DHX.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS555BGE/ENCFF044LIA.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS820SXP/ENCFF049QIP.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS023JCN/ENCFF600UQU.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS705XRW/ENCFF173JOL.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS511ZVG/ENCFF100YYU.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS021NLC/ENCFF100EPL.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS112SEO/ENCFF007EDQ.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS869GJQ/ENCFF259PEY.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS996RLF/ENCFF903XBV.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS710VQU/ENCFF349CHO.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS961BBX/ENCFF395SXY.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS806IYJ/ENCFF563QXX.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS206PUV/ENCFF322UJU.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS648NSQ/ENCFF545PJV.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS632QXG/ENCFF018PZX.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS365LJQ/ENCFF814ABW.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS538ZJX/ENCFF193WEX.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS734JMT/ENCFF118JEI.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS112SEO/ENCFF860RTY.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS869GJQ/ENCFF399UWQ.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS863SFU/ENCFF400SRZ.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS534SPQ/ENCFF290MLG.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS511ZVG/ENCFF816UQV.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS021NLC/ENCFF141IXT.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS735OAR/ENCFF132YCF.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS580WTV/ENCFF840OVC.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS271WJL/ENCFF291EKY.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS975OUN/ENCFF219UJG.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS741WNS/ENCFF693YCD.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS996RLF/ENCFF077MDV.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS710VQU/ENCFF828VAM.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS075YII/ENCFF298BEF.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS020DQC/ENCFF099FKC.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS629ZGV/ENCFF791WUV.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS870VUM/ENCFF767KXS.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS165LTN/ENCFF850YMO.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS559YLX/ENCFF924HBV.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS481ZAB/ENCFF099TJN.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS238NAR/ENCFF660UTF.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS375FZQ/ENCFF400LRT.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS944CBA/ENCFF041RNG.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS593PKA/ENCFF586RUA.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS474NOC/ENCFF866EVJ.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS966NKN/ENCFF875QHC.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS944CBA/ENCFF373TKM.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS593PKA/ENCFF985LGZ.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS474NOC/ENCFF388HXU.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS944CBA/ENCFF281OVX.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS474NOC/ENCFF469VMX.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS593PKA/ENCFF466MIS.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCB
filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS825BLU/ENCFF731THW.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS200JOD/ENCFF319JFG.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS417JEU/ENCFF901XCR.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS155WDP/ENCFF010XLY.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS155WDP/ENCFF352BIC.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS756BZF/ENCFF149ZCL.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS496CPG/ENCFF118YUM.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS271WJL/ENCFF413URT.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS601OTT/ENCFF129TRI.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS958FWY/ENCFF128WFF.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS200JOD/ENCFF069HBW.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS417JEU/ENCFF503KKJ.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS165LTN/ENCFF210MFP.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS341KAA/ENCFF478OYU.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS789UUH/ENCFF305AFY.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS372XQF/ENCFF077ICY.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS100HNS/ENCFF347IUQ.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS411JUI/ENCFF222UTL.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS411JUI/ENCFF011DHD.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS713BMM/ENCFF308FKQ.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS654ADT/ENCFF844NIJ.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS434FZQ/ENCFF653DJK.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS668AFC/ENCFF120ZKG.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS524YKH/ENCFF378UKJ.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS105TFS/ENCFF688QOM.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS777OZT/ENCFF602HCV.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS119CST/ENCFF460RWK.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS060KJN/ENCFF059KVJ.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS632QXG/ENCFF327HID.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS823URA/ENCFF414AZQ.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS692CKU/ENCFF426WCQ.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS975OUN/ENCFF626GVO.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS759AII/ENCFF769NNF.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS911SOZ/ENCFF736BIN.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS559YLX/ENCFF874MDG.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS034WOR/ENCFF591MXM.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS572IFJ/ENCFF852HOG.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS820SXP/ENCFF948VKA.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS023JCN/ENCFF140CNM.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS239VAD/ENCFF100RGC.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS239VAD/ENCFF927MKK.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS914REQ/ENCFF347RJG.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS734JMT/ENCFF136ANW.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS725WGH/ENCFF886GEY.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS375FZQ/ENCFF766TYC.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS731WFT/ENCFF608CTI.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS420JRY/ENCFF533BDU.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS892JRQ/ENCFF561ZTT.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS966NKN/ENCFF545SNN.filtered.bam: Single-end
# /zata/zippy/ramirezc/splice-model-benchmark/golden_standard/snakemake_output/ENCBS705XRW/ENCFF443TQL.filtered.bam: Single-end

# %% [markdown]
# In the future when working with stranded data (forward, reverse), know that it will affect how the BAM files are parsed. For example in a pysam iterator:
#
# ```python
# for chrom in chroms:
#     for read in samfile.fetch(chrom):
#         if library_type == 'forward':
#             return '-' if read.is_reverse else '+'
#         elif library_type == 'reverse':
#             return '+' if read.is_reverse else '-'
# ```
#
# For unstranded data, you cannot determine the strand of the read, so the data must remain strand agnostic.

# %% [markdown]
# Count number of BAM files coming from unstranded libraries

# %%
metadata = pl.read_csv("/zata/zippy/ramirezc/splice-model-benchmark/golden_standard/biosample_matched_rna_seq_experiments.tsv", separator="\t")
display(metadata.select("Assay", "Library strand specific").to_struct().value_counts())
# Out:
# shape: (3, 2)
# ┌─────────────────────────────────┬───────┐
# │                                 ┆ count │
# │ ---                             ┆ ---   │
# │ struct[2]                       ┆ u32   │
# ╞═════════════════════════════════╪═══════╡
# │ {"long read RNA-seq","unstrand… ┆ 69    │
# │ {"total RNA-seq","reverse"}     ┆ 95    │
# │ {"long read RNA-seq","forward"… ┆ 32    │
# └─────────────────────────────────┴───────┘
